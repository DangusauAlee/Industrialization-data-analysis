# 314                        Cider  Hong Kong  NaN
# 325                         NIUM  Singapore  NaN
# 346                        Carro  Singapore  NaN
# 351                   Matrixport  Singapore  NaN
# 379                      PatSnap  Singapore  NaN
# 409                    Carousell  Singapore  NaN
# 526                     bolttech  Singapore  NaN
# 582   Advance Intelligence Group  Singapore  NaN
# 645                       Moglix  Singapore  NaN
# 660                  Amber Group  Hong Kong  NaN
# 774                          FTX    Bahamas  NaN
# 836                    HyalRoute  Singapore  NaN
# 918                         Trax  Singapore  NaN
# 1081                       WeLab  Hong Kong  NaN
#
# ...

# %%
df.loc[(df.Country == 'Singapore') | (df.Country == 'Hong Kong') | (df.Country == 'Bahamas') ,['Company','Country','City','Industry']]
# Out:
#                          Company    Country            City  \
# 186                     FinAccel  Singapore             NaN
# 214                Babel Finance  Hong Kong       Hong Kong
# 222                Coda Payments  Singapore             NaN
# 250                          ONE  Singapore             NaN
# 302                    Ninja Van  Singapore             NaN
# 314                        Cider  Hong Kong             NaN
# 325                         NIUM  Singapore             NaN
# 346                        Carro  Singapore             NaN
# 351                   Matrixport  Singapore             NaN
# 379                      PatSnap  Singapore             NaN
# 409                    Carousell  Singapore             NaN
# 526                     bolttech  Singapore             NaN
# 582   Advance Intelligence Group  Singapore             NaN
# 645                       Moglix  Singapore             NaN
# 660                  Amber Group  Hong Kong             NaN
# ...

# %%
df.iloc[[186,222,250,302,325,346,351,379,409,526,582,645,836,918],[5]]='Singapore'

# %%
df.iloc[[660,214,314,1081],[5]]='Central'

# %%
df.iloc[[774],[5]]='Nassau'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Updated at                  1199 non-null   object
#  1   Company                     1199 non-null   object
#  2   Last Valuation (Billion $)  1199 non-null   float64
#  3   Date Joined                 1199 non-null   object
#  4   Year Joined                 1199 non-null   int64
#  5   City                        1199 non-null   object
#  6   Country                     1199 non-null   object
#  7   Industry                    1199 non-null   object
#  8   Investors                   1199 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 84.4+ KB

# %%
df.nunique()
# Out:
# Updated at                     279
# Company                       1196
# Last Valuation (Billion $)     225
# Date Joined                    708
# Year Joined                     13
# City                           283
# Country                         49
# Industry                        20
# Investors                     1183
# dtype: int64

# %%
df['Updated at'].unique()
# Out:
# array(['10/31/2022, 2:37:05 AM', '10/31/2022, 2:37:04 AM',
#        '10/31/2022, 2:36:06 AM', '10/31/2022, 2:36:04 AM',
#        '10/31/2022, 2:34:41 AM', '10/31/2022, 2:37:16 AM',
#        '10/31/2022, 2:37:15 AM', '10/31/2022, 2:37:14 AM',
#        '10/31/2022, 2:37:13 AM', '10/31/2022, 2:37:12 AM',
#        '10/31/2022, 2:37:11 AM', '10/31/2022, 2:37:10 AM',
#        '10/31/2022, 2:37:09 AM', '10/31/2022, 2:37:08 AM',
#        '10/31/2022, 2:37:07 AM', '10/31/2022, 2:37:06 AM',
#        '10/31/2022, 2:37:03 AM', '10/31/2022, 2:36:13 AM',
#        '10/31/2022, 2:36:12 AM', '10/31/2022, 2:36:11 AM',
#        '10/31/2022, 2:36:10 AM', '10/31/2022, 2:36:09 AM',
#        '10/31/2022, 2:36:08 AM', '10/31/2022, 2:36:07 AM',
#        '10/31/2022, 2:36:05 AM', '10/31/2022, 2:36:01 AM',
#        '10/31/2022, 2:35:57 AM', '10/31/2022, 2:35:56 AM',
#        '10/31/2022, 2:35:54 AM', '10/31/2022, 2:35:52 AM',
#        '10/31/2022, 2:35:51 AM', '10/31/2022, 2:35:50 AM',
# ...

# %%
df['Data_collection_time'] = pd.to_datetime(df['Updated at'], infer_datetime_format=True).dt.date
df['Launch year'] = df['Year Joined']
df['Launch date'] = pd.to_datetime(df['Date Joined'], infer_datetime_format=True).dt.date

# %%
df['Updated at']
# Out:
# 0       10/31/2022, 2:37:05 AM
# 1       10/31/2022, 2:37:05 AM
# 2       10/31/2022, 2:37:04 AM
# 3       10/31/2022, 2:37:04 AM
# 4       10/31/2022, 2:37:04 AM
#                  ...
# 1194    10/31/2022, 2:32:42 AM
# 1195    10/31/2022, 2:32:38 AM
# 1196    10/31/2022, 2:33:10 AM
# 1197    10/31/2022, 2:33:05 AM
# 1198    10/31/2022, 2:35:27 AM
# Name: Updated at, Length: 1199, dtype: object

# %%
df.drop(['Updated at','Year Joined','Date Joined','Investors'], axis=1, inplace=True)

# %%
df.nunique()
# Out:
# Company                       1196
# Last Valuation (Billion $)     225
# City                           283
# Country                         49
# Industry                        20
# Data_collection_time             1
# Launch year                     13
# Launch date                    708
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     1199 non-null   object
#  1   Last Valuation (Billion $)  1199 non-null   float64
#  2   City                        1199 non-null   object
#  3   Country                     1199 non-null   object
#  4   Industry                    1199 non-null   object
#  5   Data_collection_time        1199 non-null   object
#  6   Launch year                 1199 non-null   int64
#  7   Launch date                 1199 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 75.1+ KB

# %%
df.Company.value_counts()
# Out:
# Branch              2
# Bolt                2
# Fabric              2
# Esusu               1
# Gymshark            1
#                    ..
# Turing              1
# GlobalBees          1
# UISEE Technology    1
# 56PINGTAI           1
# Veepee              1
# Name: Company, Length: 1196, dtype: int64

# %%
df.loc[(df.Company == 'Branch') | (df.Company == 'Bolt') | (df.Company == 'Fabric')]
# Out:
#      Company  Last Valuation (Billion $)           City        Country  \
# 73    Branch                        1.05       Columbus  United States
# 158   Fabric                        1.50       Bellevue  United States
# 287   Fabric                        1.00       New York  United States
# 766     Bolt                       11.00  San Francisco  United States
# 1043  Branch                        4.00   Redwood City  United States
# 1060    Bolt                        8.40        Tallinn        Estonia
#
#                                  Industry Data_collection_time  Launch year  \
# 73                                Fintech           2022-10-31         2022
# 158       E-commerce & direct-to-consumer           2022-10-31         2022
# 287   Supply chain, logistics, & delivery           2022-10-31         2021
# 766                               Fintech           2022-10-31         2021
# 1043          Mobile & telecommunications           2022-10-31         2018
# ...

# %%
df.Industry.value_counts()
# Out:
# Fintech                                253
# Internet software & services           231
# E-commerce & direct-to-consumer        109
# Health                                  95
# Artificial intelligence                 75
# Supply chain, logistics, & delivery     68
# Other                                   64
# Cybersecurity                           56
# Data management & analytics             45
# Mobile & telecommunications             39
# Hardware                                38
# Auto & transportation                   37
# Edtech                                  32
# Consumer & retail                       27
# Travel                                  14
# Artificial Intelligence                 11
# Cybersecurity                            2
# Auto & transportation                    1
# Artificial intelligence                  1
# Consumer & retail                        1
# Name: Industry, dtype: int64

# %%
df['Industry']=df.Industry.str.replace(r'Artificial intelligence','Artificial Intelligence').str.strip()

# %%
df.Industry.value_counts()
# Out:
# Fintech                                253
# Internet software & services           231
# E-commerce & direct-to-consumer        109
# Health                                  95
# Artificial Intelligence                 87
# Supply chain, logistics, & delivery     68
# Other                                   64
# Cybersecurity                           58
# Data management & analytics             45
# Mobile & telecommunications             39
# Hardware                                38
# Auto & transportation                   38
# Edtech                                  32
# Consumer & retail                       28
# Travel                                  14
# Name: Industry, dtype: int64

# %%
df.Country.value_counts()
# Out:
# United States           645
# China                   173
# India                    70
# United Kingdom           47
# Germany                  29
# France                   24
# Israel                   23
# Canada                   19
# South Korea              16
# Brazil                   16
# Singapore                14
# Mexico                    8
# Sweden                    8
# Australia                 8
# Hong Kong                 7
# Netherlands               7
# Indonesia                 7
# Japan                     6
# Ireland                   6
# Switzerland               6
# Norway                    5
# Spain                     5
# Finland                   4
# Thailand                  3
# Turkey                    3
# Colombia                  3
# Belgium                   3
# United Arab Emirates      3
# Austria                   2
# South Africa              2
# Vietnam                   2
# Philippines               2
# Denmark                   2
# ...

# %%
df.City.value_counts().sort_values(ascending=False).head(30)
# Out:
# San Francisco    169
# New York         115
# Beijing           62
# Shanghai          44
# London            37
# Bengaluru         31
# Boston            22
# Shenzhen          20
# Palo Alto         20
# Berlin            20
# Paris             19
# Chicago           17
# Mountain View     17
# Hangzhou          16
# Seoul             15
# Singapore         14
# Tel Aviv          12
# Sao Paulo         12
# Redwood City      12
# San Mateo         11
# Austin            11
# Seattle           10
# Cambridge         10
# Mumbai             9
# Los Angeles        9
# Sunnyvale          8
# San Jose           8
# Jakarta            7
# Stockholm          7
# Denver             7
# Name: City, dtype: int64

# %%
df.describe()
# Out:
#        Last Valuation (Billion $)  Launch year
# count                 1199.000000  1199.000000
# mean                     3.225588  2020.158465
# std                      7.601195     1.981949
# min                      1.000000  2007.000000
# 25%                      1.100000  2019.000000
# 50%                      1.570000  2021.000000
# 75%                      3.000000  2021.000000
# max                    140.000000  2022.000000

# %%
df.describe(include=object).transpose()
# Out:
#                      count unique            top  freq
# Company               1199   1196         Branch     2
# City                  1199    283  San Francisco   169
# Country               1199     49  United States   645
# Industry              1199     15        Fintech   253
# Data_collection_time  1199      1     2022-10-31  1199
# Launch date           1199    708     2021-07-13     9

# %%
df.drop([1121, 1195,1079,1181], inplace=True)

# %%
df.drop([246,1188,1078,982,1187,981,1077,774,1076,1076,1194,980,1120,1142,773,246], inplace=True)

# %%
df.describe(include='all')
# Out:
#        Company  Last Valuation (Billion $)           City        Country  \
# count     1181                 1181.000000           1181           1181
# unique    1178                         NaN            279             48
# top     Branch                         NaN  San Francisco  United States
# freq         2                         NaN            164            637
# mean       NaN                    2.556376            NaN            NaN
# std        NaN                    2.436441            NaN            NaN
# min        NaN                    1.000000            NaN            NaN
# 25%        NaN                    1.080000            NaN            NaN
# 50%        NaN                    1.520000            NaN            NaN
# 75%        NaN                    3.000000            NaN            NaN
# max        NaN                   15.500000            NaN            NaN
#
#        Industry Data_collection_time  Launch year Launch date
# ...

# %%
df.to_csv('companies.csv')
